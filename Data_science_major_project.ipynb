# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/adult.csv")

# %%
#print the data in dataset
data
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
#Drop The Duplicates in data

data.drop_duplicates()
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
data.dropna()
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
data.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %% [markdown]
# # **Rename The columns**

# %%
data.columns=data.columns.str.replace('39','Age')
data.columns=data.columns.str.replace('77516','Fnlwgt')
data.columns = data.columns.str.replace('Never-married', 'marital_status')
data.columns = data.columns.str.replace('Adm-clerical', 'occupation')
data.columns = data.columns.str.replace('Not-in-family', 'relationship')
data.columns = data.columns.str.replace('United-States', 'native_country')
data.columns = data.columns.str.replace('White','race')
data.columns=data.columns.str.replace('Bachelors','Education')
data.columns=data.columns.str.replace('Male','sex')
data.columns=data.columns.str.replace('13','education_num')
data.columns=data.columns.str.replace('2174','capital_gain')
data.columns=data.columns.str.replace('0','capital_loss')
data.columns=data.columns.str.replace('<=K','income')
data.columns = data.columns.str.replace('State-gov', 'Workclass')
data.columns=data.columns.str.replace('4capital_loss','hours_per_week')

# %%
data
# Out:
#        Age          Workclass   Fnlwgt    Education   education_num  \
# 0       50   Self-emp-not-inc    83311    Bachelors              13
# 1       38            Private   215646      HS-grad               9
# 2       53            Private   234721         11th               7
# 3       28            Private   338409    Bachelors              13
# 4       37            Private   284582      Masters              14
# ...    ...                ...      ...          ...             ...
# 32555   27            Private   257302   Assoc-acdm              12
# 32556   40            Private   154374      HS-grad               9
# 32557   58            Private   151910      HS-grad               9
# 32558   22            Private   201490      HS-grad               9
# 32559   52       Self-emp-inc   287927      HS-grad               9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.select_dtypes(include=['object']).columns
data.select_dtypes(include=['object']).columns
# Out:
# Index([' Workclass', ' Education', ' marital_status', ' occupation',
#        ' relationship', ' race', ' sex', ' native_country', ' income'],
#       dtype='object')

# %%
#Finding the special characters in the data frame 
data.isin(['?']).sum(axis=0)
# Out:
# Age                0
#  Workclass         0
#  Fnlwgt            0
#  Education         0
#  education_num     0
#  marital_status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital_gain      0
#  capital_loss      0
#  hours_per_week    0
#  native_country    0
#  income            0
# dtype: int64

# %%
#running a loop of value_counts of each column to find out unique values. 
for c in data.columns:
    print ("---- %s ---" % c)
    print (data[c].value_counts())
# Out:
# ---- Age ---
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64
# ----  Workclass ---
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  Workclass, dtype: int64
# ----  Fnlwgt ---
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name:  Fnlwgt, Length: 21647, dtype: int64
# ----  Education ---
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
# ...

# %%
data2 = pd.DataFrame(data)
for col in data2.columns:
    if 'Age' in col:
        del data2[col]

# %%
data2
# Out:
#                Workclass   Fnlwgt    Education   education_num  \
# 0       Self-emp-not-inc    83311    Bachelors              13
# 1                Private   215646      HS-grad               9
# 2                Private   234721         11th               7
# 3                Private   338409    Bachelors              13
# 4                Private   284582      Masters              14
# ...                  ...      ...          ...             ...
# 32555            Private   257302   Assoc-acdm              12
# 32556            Private   154374      HS-grad               9
# 32557            Private   151910      HS-grad               9
# 32558            Private   201490      HS-grad               9
# 32559       Self-emp-inc   287927      HS-grad               9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.columns = [x.strip() for x in data.columns]

# %%
data
# Out:
#        Age          Workclass  Fnlwgt    Education  education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# # **string to  Integer**

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['income']= label_encoder.fit_transform(data['income'])
data['Workclass']= label_encoder.fit_transform(data['Workclass'])
data['Education']= label_encoder.fit_transform(data['Education'])
data['marital_status']= label_encoder.fit_transform(data['marital_status'])
data['occupation']= label_encoder.fit_transform(data['occupation'])
data['relationship']= label_encoder.fit_transform(data['relationship'])
data['race']= label_encoder.fit_transform(data['race'])
data['sex']= label_encoder.fit_transform(data['sex'])
data['native_country']= label_encoder.fit_transform(data['native_country'])

data['income'].unique()
# Out:
# array([0, 1])

# %%
data['Education'].unique()
# Out:
# array([ 9, 11,  1, 12,  6, 15,  7,  8,  5, 10, 14,  4,  0,  3, 13,  2])

# %%
data
# income >50=1 and <=50k = 0
# Out:
#        Age  Workclass  Fnlwgt  Education  education_num  marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
#to find the unique column values
data.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# income                2
# dtype: int64

# %%
import matplotlib.pyplot as plt
data.hist(xrot=10, figsize=(20,20), color = 'green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3cae21c190>,
# ...
#       dtype=object)

# %%
 
data.groupby('hours_per_week').income.mean().plot(kind='bar')

# %%
#plotting a bar graph for Education against Income to see the co-relation between these columns 
data.groupby('Education').income.mean().plot(kind='bar')

# %%
sns.countplot(data['occupation'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('count of occupation ')
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load the tips dataset present by default in seaborn
sns.set_style('darkgrid')

# make a countplot
sns.countplot(x ='income', data = data)
#0=  >50k and <=50k  ==0

# %%
sns.distplot(data['income'])
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title('income of dataset')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # **TRAINING AND TESTING MODEL**

# %%
x  = data.drop(['income'], axis=1)
y = data['income']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Decision Tree**

# %%
model=DecisionTreeClassifier()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=0)

# %%
model.fit(x_train,y_train)
pre=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(accuracy_score(y_test,pre))
# Out:
# 0.8103501228501229

# %%
print(confusion_matrix(y_test,pre))
# Out:
# [[4328  629]
#  [ 606  949]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
print('Precision: %.3f' % precision_score(y_test, pre))
print('Recall: %.3f' % recall_score(y_test, pre))
print('F1 Score: %.3f' % f1_score(y_test, pre))
print('accuracy score',accuracy_score(y_test,pre))
print('confusion matrix',confusion_matrix(y_test,pre))
# Out:
# Precision: 0.601
# Recall: 0.610
# F1 Score: 0.606
# accuracy score 0.8103501228501229
# confusion matrix [[4328  629]
#  [ 606  949]]

# %%
cx=confusion_matrix(y_test,pre)
sns.heatmap(pd.DataFrame(cx),annot=True,fmt='g')
sns.set(rc={'figure.figsize':(3,3)})
plt.tight_layout()
plt.title('Confusion Matrix',y=1.1)
plt.ylabel('Actual Values')
plt.xlabel('Predicted Value')
# Out:
# Text(0.5, 15.0, 'Predicted Value')

# %% [markdown]
# **RandomForest**

# %%
from sklearn.ensemble import RandomForestClassifier
#fitting the data to the model
model1 = RandomForestClassifier()
model1.fit(x_train,y_train)
#predicting the model
pre1 = model1.predict(x_test)

# %%
print('Precision: %.3f' % precision_score(y_test, pre1))
print('Recall: %.3f' % recall_score(y_test, pre1))
print('F1 Score: %.3f' % f1_score(y_test, pre1))
print('accuracy score',accuracy_score(y_test,pre1))
print('confusion matrix',confusion_matrix(y_test,pre1))
# Out:
# Precision: 0.736
# Recall: 0.616
# F1 Score: 0.671
# accuracy score 0.855497542997543
# confusion matrix [[4613  344]
#  [ 597  958]]

# %%
cx=confusion_matrix(y_test,pre1)
sns.heatmap(pd.DataFrame(cx),annot=True,fmt='g')
sns.set(rc={'figure.figsize':(3,3)})
plt.tight_layout()
plt.title('Confusion Matrix',y=1.1)
plt.ylabel('Actual Values')
plt.xlabel('Predicted Value')
# Out:
# Text(0.5, 3.5, 'Predicted Value')

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
#fitting the data to the model
model2=LogisticRegression()
model2.fit(x_train,y_train)
#predicting the model
pre2 = model2.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
print('Precision: %.3f' % precision_score(y_test, pre2))
print('Recall: %.3f' % recall_score(y_test, pre2))
print('F1 Score: %.3f' % f1_score(y_test, pre2))
print('accuracy score',accuracy_score(y_test,pre2))
print('confusion matrix',confusion_matrix(y_test,pre2))
# Out:
# Precision: 0.599
# Recall: 0.291
# F1 Score: 0.392
# accuracy score 0.7842444717444718
# confusion matrix [[4655  302]
#  [1103  452]]

# %%
cx=confusion_matrix(y_test,pre2)
sns.heatmap(pd.DataFrame(cx),annot=True,fmt='g')
sns.set(rc={'figure.figsize':(3,3)})
plt.tight_layout()
plt.title('Confusion Matrix',y=1.1)
plt.ylabel('Actual Values')
plt.xlabel('Predicted Value')
# Out:
# Text(0.5, 3.5, 'Predicted Value')

# %% [markdown]
# **KNeighborsClassifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
#fitting the data to the model
model4 = KNeighborsClassifier()
model4.fit(x_train,y_train)
#predicting the model
pre3 = model4.predict(x_test)

# %%
print('Precision: %.3f' % precision_score(y_test, pre3))
print('Recall: %.3f' % recall_score(y_test, pre3))
print('F1 Score: %.3f' % f1_score(y_test, pre3))
print('accuracy score',accuracy_score(y_test,pre3))
print('confusion matrix',confusion_matrix(y_test,pre3))
# Out:
# Precision: 0.537
# Recall: 0.310
# F1 Score: 0.393
# accuracy score 0.7713452088452089
# confusion matrix [[4541  416]
#  [1073  482]]

# %%
cx=confusion_matrix(y_test,pre3)
sns.heatmap(pd.DataFrame(cx),annot=True,fmt='g')
sns.set(rc={'figure.figsize':(3,3)})
plt.tight_layout()
plt.title('Confusion Matrix',y=1.1)
plt.ylabel('Actual Values')
plt.xlabel('Predicted Value')
# Out:
# Text(0.5, 3.5, 'Predicted Value')

# %% [markdown]
# **SVC**

# %%
from sklearn.svm import SVC
#fitting the data to the model
model5 = SVC()
model5.fit(x_train,y_train)
#predicting the model
pre4 = model5.predict(x_test)

# %%
print('Precision: %.3f' % precision_score(y_test, pre4))
print('Recall: %.3f' % recall_score(y_test, pre4))
print('F1 Score: %.3f' % f1_score(y_test, pre4))
print('accuracy score',accuracy_score(y_test,pre4))
print('confusion matrix',confusion_matrix(y_test,pre4))
# Out:
# Precision: 0.957
# Recall: 0.142
# F1 Score: 0.247
# accuracy score 0.7936117936117936
# confusion matrix [[4947   10]
#  [1334  221]]

# %%
cx=confusion_matrix(y_test,pre4)
sns.heatmap(pd.DataFrame(cx),annot=True,fmt='g')
sns.set(rc={'figure.figsize':(3,3)})
plt.tight_layout()
plt.title('Confusion Matrix',y=1.1)
plt.ylabel('Actual Values')
plt.xlabel('Predicted Value')
# Out:
# Text(0.5, 3.5, 'Predicted Value')

# %% [markdown]
# # Report the accuracy of all models

# %% [markdown]
# **Decision Tree**--accuracy score 0.8103501228501229
# <p> **Random Forest**--accuracy score 0.855497542997543
# <p>**Logistic Regression**--accuracy score 0.7842444717444718
# <p>**KNN classifier**--accuracy score 0.7713452088452089
# <p>**SVC**--accuracy score 0.7936117936117936
